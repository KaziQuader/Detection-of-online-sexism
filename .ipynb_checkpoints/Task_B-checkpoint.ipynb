# %% [markdown]
# # TASK B - Category of Sexism

# %%
# # Install necessary libraries and make sure you have the correct python version installed in your computer
# !pip install pandas numpy
# !pip3 install wordcloud
# !pip3 install imbalanced-learn
# !pip3 install tensorflow
# !pip3 install keras

# %%
# Load, explore and plot data
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline

# %% [markdown]
# # Reading csv file and transforming the dataframe

# %%
df = pd.read_csv('train_all_tasks.csv', usecols=['text', 'label_sexist', 'label_category'])
df = df[df['label_sexist'] == 'sexist']
# giving numerical values to categories 
df['label_category'] = df['label_category'].map({'1. threats, plans to harm and incitement': 0, '2. derogation': 1, '3. animosity': 2, 
                                                 '4. prejudiced discussions': 3})
df.describe()
df.groupby('label_category').describe().T
# Out:
# label_category                                                       0  \
# text         count                                                 310
#              unique                                                310
#              top     fuck her off with a nine mm this is what you g...
#              freq                                                    1
# label_sexist count                                                 310
#              unique                                                  1
#              top                                                sexist
#              freq                                                  310
#
# label_category                                                       1  \
# text         count                                                1590
#              unique                                               1590
#              top     just the inside of your wallet: cash, bank car...
#              freq                                                    1
# label_sexist count                                                1590
#              unique                                                  1
#              top                                                sexist
#              freq                                                 1590
#
# label_category                                                       2  \
# text         count                                                1165
#              unique                                               1165
#              top     How about I talk shit to an idiot like you? Ar...
#              freq                                                    1
# label_sexist count                                                1165
#              unique                                                  1
#              top                                                sexist
#              freq                                                 1165
#
# label_category                                                       3
# text         count                                                 333
#              unique                                                333
#              top     If you want to attack culture and norms you ha...
#              freq                                                    1
# label_sexist count                                                 333
#              unique                                                  1
#              top                                                sexist
#              freq                                                  333

# %% [markdown]
# # Visualize categories of sexist texts

# %%
#word cloud for threats: haarm and incitement
threat_msg = df[df['label_category'] == 0]
threat_msg = str(threat_msg['text'])
threats_msg_cloud = WordCloud(width =520, height =200, stopwords = STOPWORDS, max_font_size = 50, background_color = "black", colormap = 'Pastel1').generate(threat_msg)
plt.figure(figsize=(16,10))
plt.imshow(threats_msg_cloud, interpolation = 'bilinear')
plt.axis('off') # turn off axis
plt.show()

#word cloud for derogation
derogation_msg = df[df['label_category'] == 1]
derogation_msg = str(derogation_msg['text'])
derogation_msg_cloud = WordCloud(width =520, height =200, stopwords = STOPWORDS, max_font_size = 50, background_color = "black", colormap = 'Pastel1').generate(derogation_msg)
plt.figure(figsize=(16,10))
plt.imshow(derogation_msg_cloud, interpolation = 'bilinear')
plt.axis('off') # turn off axis
plt.show()

#word cloud for animosity
animosity_msg = df[df['label_category'] == 2]
animosity_msg = str(animosity_msg['text'])
animosity_msg_cloud = WordCloud(width =520, height =200, stopwords = STOPWORDS, max_font_size = 50, background_color = "black", colormap = 'Pastel1').generate(animosity_msg)
plt.figure(figsize=(16,10))
plt.imshow(animosity_msg_cloud, interpolation = 'bilinear')
plt.axis('off') # turn off axis
plt.show()

#word cloud for prejudiced discussions
prejudiced_msg = df[df['label_category'] == 3]
prejudiced_msg = str(prejudiced_msg['text'])
prejudiced_msg_cloud = WordCloud(width =520, height =200, stopwords = STOPWORDS, max_font_size = 50, background_color = "black", colormap = 'Pastel1').generate(prejudiced_msg)
plt.figure(figsize=(16,10))
plt.imshow(prejudiced_msg_cloud, interpolation = 'bilinear')
plt.axis('off') # turn off axis
plt.show()

# %% [markdown]
# # Visualising & Fixing Imbalanced Dataset

# %%
# print("Before SMOTE: ", np.unique(y, return_counts=True))

plt.figure(figsize=(8,6))
sns.countplot(x='label_category', data = df)
plt.title('The distribution of sexist messages')
plt.show()

# %%
from imblearn.over_sampling import RandomOverSampler

# Assuming X and y are your feature matrix and target labels
# Instantiate RandomOverSampler
ros = RandomOverSampler(random_state=42)


# Fit and resample the data
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=['label_category']), df['label_category'])

df = pd.concat([X_resampled, y_resampled.rename('label_category')], axis=1)
# print(df['text'])
# print(df.drop(columns=['label_category']))

plt.figure(figsize=(8,6))
sns.countplot(x='label_category', data = df)
plt.title('The distribution of sexist messages')
plt.show()

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# 1. Train Test Split

# %%
#finding length of each text
df['text_length'] = df['text'].apply(len)

# train test split 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df['text'], df['label_category'], test_size=0.2, random_state=434)

# %% [markdown]
# 2. Tokenization of words

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# Defining pre-processing parameters
max_len = 40 
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>' # out of vocabulary token
vocab_size = 5000

# initiating tokenizer object 
tokenizer = Tokenizer(num_words = vocab_size, 
                      char_level = False,
                      oov_token = oov_tok)
tokenizer.fit_on_texts(x_train)

# Get the word_index
word_index = tokenizer.word_index
total_words = len(word_index)
total_words
# Out:
# 8715

# %% [markdown]
# 3. Padding and Sequencing

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Padding & sequencing for training data 
training_sequences = tokenizer.texts_to_sequences(x_train)
training_padded = pad_sequences(training_sequences,
                                maxlen = max_len,
                                padding = padding_type,
                                truncating = trunc_type)
print(training_padded.shape)
# Padding & sequencing for test data 
testing_sequences = tokenizer.texts_to_sequences(x_test)
testing_padded = pad_sequences(testing_sequences,
                               maxlen = max_len,
                               padding = padding_type,
                               truncating = trunc_type)
print(testing_padded.shape)
# Out:
# (5088, 40)
# (1272, 40)

# %% [markdown]
# 4. Word Embedding Using one-hot encoding technique

# %%
# One hot encoding 
from tensorflow.keras.preprocessing.text import one_hot

encoded_train_docs = [one_hot(d, vocab_size) for d in x_train]
padded_train_docs = pad_sequences(encoded_train_docs, maxlen=max_len, padding='post')
print(padded_train_docs.shape)

encoded_test_docs = [one_hot(d, vocab_size) for d in x_test]
padded_test_docs = pad_sequences(encoded_test_docs, maxlen=max_len, padding='post')
print(padded_test_docs.shape)
# Out:
# (5088, 40)
# (1272, 40)

# %% [markdown]
# # Building and training models

# %% [markdown]
# 1. Building LSTM model

# %%
# Modeling
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,  Dense, Embedding, Dropout, GRU

# %%
# Define parameter
n_lstm = 128
drop_lstm = 0.3
embedding_dim = 16
num_of_epochs = 80
batch_size = 64


# Define LSTM Model 
model1 = Sequential()
model1.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model1.add(LSTM(n_lstm))
model1.add(Dropout(drop_lstm))
model1.add(Dense(4, activation='softmax'))
model1.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam' , metrics = ['accuracy'])

model1.summary()

history = model1.fit(padded_train_docs,
                     y_train,
                     epochs=num_of_epochs, 
                     batch_size=batch_size,
                     validation_data=(padded_test_docs, y_test),
                     verbose=2)

model1.evaluate(padded_test_docs, y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 40, 16)            80000
#
#  lstm (LSTM)                 (None, 128)               74240
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 154756 (604.52 KB)
# Trainable params: 154756 (604.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/80
# 80/80 - 2s - loss: 1.3315 - accuracy: 0.3337 - val_loss: 1.1470 - val_accuracy: 0.4646 - 2s/epoch - 30ms/step
# Epoch 2/80
# 80/80 - 2s - loss: 0.9645 - accuracy: 0.5527 - val_loss: 1.0192 - val_accuracy: 0.5369 - 2s/epoch - 21ms/step
# Epoch 3/80
# 80/80 - 2s - loss: 0.7232 - accuracy: 0.6649 - val_loss: 0.7518 - val_accuracy: 0.6667 - 2s/epoch - 21ms/step
# Epoch 4/80
# 80/80 - 2s - loss: 0.5607 - accuracy: 0.7309 - val_loss: 0.7632 - val_accuracy: 0.6690 - 2s/epoch - 21ms/step
# Epoch 5/80
# 80/80 - 2s - loss: 0.4926 - accuracy: 0.7736 - val_loss: 0.6380 - val_accuracy: 0.7186 - 2s/epoch - 21ms/step
# Epoch 6/80
# 80/80 - 2s - loss: 0.4130 - accuracy: 0.8096 - val_loss: 0.7831 - val_accuracy: 0.7248 - 2s/epoch - 21ms/step
# Epoch 7/80
# 80/80 - 2s - loss: 0.3353 - accuracy: 0.8634 - val_loss: 0.8003 - val_accuracy: 0.7429 - 2s/epoch - 21ms/step
# Epoch 8/80
# 80/80 - 2s - loss: 0.2805 - accuracy: 0.8974 - val_loss: 0.7706 - val_accuracy: 0.7461 - 2s/epoch - 21ms/step
# Epoch 9/80
# 80/80 - 2s - loss: 0.2477 - accuracy: 0.9180 - val_loss: 0.7883 - val_accuracy: 0.7555 - 2s/epoch - 21ms/step
# Epoch 10/80
# 80/80 - 2s - loss: 0.2120 - accuracy: 0.9292 - val_loss: 0.9059 - val_accuracy: 0.7579 - 2s/epoch - 21ms/step
# Epoch 11/80
# 80/80 - 2s - loss: 0.2410 - accuracy: 0.9226 - val_loss: 0.9751 - val_accuracy: 0.7469 - 2s/epoch - 21ms/step
# Epoch 12/80
# 80/80 - 2s - loss: 0.1800 - accuracy: 0.9448 - val_loss: 1.0003 - val_accuracy: 0.7500 - 2s/epoch - 21ms/step
# Epoch 13/80
# 80/80 - 2s - loss: 0.1341 - accuracy: 0.9634 - val_loss: 1.0451 - val_accuracy: 0.7492 - 2s/epoch - 21ms/step
# Epoch 14/80
# 80/80 - 2s - loss: 0.1150 - accuracy: 0.9666 - val_loss: 1.1252 - val_accuracy: 0.7563 - 2s/epoch - 21ms/step
# Epoch 15/80
# 80/80 - 2s - loss: 0.1184 - accuracy: 0.9636 - val_loss: 0.9572 - val_accuracy: 0.7697 - 2s/epoch - 21ms/step
# Epoch 16/80
# 80/80 - 2s - loss: 0.1318 - accuracy: 0.9638 - val_loss: 1.2150 - val_accuracy: 0.7429 - 2s/epoch - 21ms/step
# Epoch 17/80
# 80/80 - 2s - loss: 0.0930 - accuracy: 0.9729 - val_loss: 1.0577 - val_accuracy: 0.7618 - 2s/epoch - 21ms/step
# Epoch 18/80
# 80/80 - 2s - loss: 0.0747 - accuracy: 0.9786 - val_loss: 1.2023 - val_accuracy: 0.7594 - 2s/epoch - 21ms/step
# Epoch 19/80
# 80/80 - 2s - loss: 0.0792 - accuracy: 0.9780 - val_loss: 1.1901 - val_accuracy: 0.7539 - 2s/epoch - 21ms/step
# Epoch 20/80
# 80/80 - 2s - loss: 0.0741 - accuracy: 0.9768 - val_loss: 1.2330 - val_accuracy: 0.7602 - 2s/epoch - 21ms/step
# Epoch 21/80
# 80/80 - 2s - loss: 0.0859 - accuracy: 0.9729 - val_loss: 1.1295 - val_accuracy: 0.7634 - 2s/epoch - 21ms/step
# Epoch 22/80
# 80/80 - 2s - loss: 0.1386 - accuracy: 0.9597 - val_loss: 1.1286 - val_accuracy: 0.7539 - 2s/epoch - 21ms/step
# Epoch 23/80
# 80/80 - 2s - loss: 0.0885 - accuracy: 0.9739 - val_loss: 1.1431 - val_accuracy: 0.7586 - 2s/epoch - 22ms/step
# Epoch 24/80
# 80/80 - 2s - loss: 0.0495 - accuracy: 0.9853 - val_loss: 1.2521 - val_accuracy: 0.7657 - 2s/epoch - 21ms/step
# Epoch 25/80
# 80/80 - 2s - loss: 0.0550 - accuracy: 0.9849 - val_loss: 1.1951 - val_accuracy: 0.7618 - 2s/epoch - 21ms/step
# Epoch 26/80
# 80/80 - 2s - loss: 0.0483 - accuracy: 0.9858 - val_loss: 1.1844 - val_accuracy: 0.7673 - 2s/epoch - 21ms/step
# Epoch 27/80
# 80/80 - 2s - loss: 0.0374 - accuracy: 0.9876 - val_loss: 1.2520 - val_accuracy: 0.7681 - 2s/epoch - 22ms/step
# Epoch 28/80
# 80/80 - 2s - loss: 0.0898 - accuracy: 0.9735 - val_loss: 1.2962 - val_accuracy: 0.7555 - 2s/epoch - 22ms/step
# Epoch 29/80
# 80/80 - 2s - loss: 0.0656 - accuracy: 0.9790 - val_loss: 1.1889 - val_accuracy: 0.7712 - 2s/epoch - 21ms/step
# Epoch 30/80
# 80/80 - 2s - loss: 0.0353 - accuracy: 0.9888 - val_loss: 1.3387 - val_accuracy: 0.7665 - 2s/epoch - 21ms/step
# Epoch 31/80
# 80/80 - 2s - loss: 0.0682 - accuracy: 0.9768 - val_loss: 1.2105 - val_accuracy: 0.7673 - 2s/epoch - 21ms/step
# Epoch 32/80
# 80/80 - 2s - loss: 0.0831 - accuracy: 0.9760 - val_loss: 1.1629 - val_accuracy: 0.7697 - 2s/epoch - 21ms/step
# Epoch 33/80
# 80/80 - 2s - loss: 0.0347 - accuracy: 0.9888 - val_loss: 1.3016 - val_accuracy: 0.7759 - 2s/epoch - 21ms/step
# Epoch 34/80
# 80/80 - 2s - loss: 0.0481 - accuracy: 0.9847 - val_loss: 1.3268 - val_accuracy: 0.7657 - 2s/epoch - 21ms/step
# Epoch 35/80
# 80/80 - 2s - loss: 0.0569 - accuracy: 0.9837 - val_loss: 1.1959 - val_accuracy: 0.7681 - 2s/epoch - 21ms/step
# Epoch 36/80
# 80/80 - 2s - loss: 0.0468 - accuracy: 0.9851 - val_loss: 1.3378 - val_accuracy: 0.7602 - 2s/epoch - 21ms/step
# Epoch 37/80
# 80/80 - 2s - loss: 0.0431 - accuracy: 0.9870 - val_loss: 1.5626 - val_accuracy: 0.7461 - 2s/epoch - 21ms/step
# Epoch 38/80
# 80/80 - 2s - loss: 0.0461 - accuracy: 0.9870 - val_loss: 1.4226 - val_accuracy: 0.7610 - 2s/epoch - 21ms/step
# Epoch 39/80
# 80/80 - 2s - loss: 0.0505 - accuracy: 0.9868 - val_loss: 1.3892 - val_accuracy: 0.7571 - 2s/epoch - 21ms/step
# Epoch 40/80
# 80/80 - 2s - loss: 0.0810 - accuracy: 0.9774 - val_loss: 1.1797 - val_accuracy: 0.7657 - 2s/epoch - 21ms/step
# Epoch 41/80
# 80/80 - 2s - loss: 0.0467 - accuracy: 0.9888 - val_loss: 1.2202 - val_accuracy: 0.7697 - 2s/epoch - 21ms/step
# Epoch 42/80
# 80/80 - 2s - loss: 0.0483 - accuracy: 0.9853 - val_loss: 1.3502 - val_accuracy: 0.7634 - 2s/epoch - 21ms/step
# Epoch 43/80
# 80/80 - 2s - loss: 0.0279 - accuracy: 0.9921 - val_loss: 1.4258 - val_accuracy: 0.7579 - 2s/epoch - 22ms/step
# Epoch 44/80
# 80/80 - 2s - loss: 0.0239 - accuracy: 0.9957 - val_loss: 1.4499 - val_accuracy: 0.7799 - 2s/epoch - 21ms/step
# Epoch 45/80
# 80/80 - 2s - loss: 0.0254 - accuracy: 0.9943 - val_loss: 1.4797 - val_accuracy: 0.7642 - 2s/epoch - 21ms/step
# Epoch 46/80
# 80/80 - 2s - loss: 0.0286 - accuracy: 0.9939 - val_loss: 1.5125 - val_accuracy: 0.7689 - 2s/epoch - 21ms/step
# Epoch 47/80
# 80/80 - 2s - loss: 0.0300 - accuracy: 0.9943 - val_loss: 1.4693 - val_accuracy: 0.7634 - 2s/epoch - 21ms/step
# Epoch 48/80
# 80/80 - 2s - loss: 0.0284 - accuracy: 0.9939 - val_loss: 1.4823 - val_accuracy: 0.7547 - 2s/epoch - 21ms/step
# Epoch 49/80
# 80/80 - 2s - loss: 0.0645 - accuracy: 0.9849 - val_loss: 1.3978 - val_accuracy: 0.7626 - 2s/epoch - 21ms/step
# Epoch 50/80
# 80/80 - 2s - loss: 0.0930 - accuracy: 0.9756 - val_loss: 1.1889 - val_accuracy: 0.7618 - 2s/epoch - 21ms/step
# Epoch 51/80
# 80/80 - 2s - loss: 0.0437 - accuracy: 0.9894 - val_loss: 1.2661 - val_accuracy: 0.7728 - 2s/epoch - 21ms/step
# Epoch 52/80
# 80/80 - 2s - loss: 0.0217 - accuracy: 0.9953 - val_loss: 1.5165 - val_accuracy: 0.7657 - 2s/epoch - 21ms/step
# Epoch 53/80
# 80/80 - 2s - loss: 0.0315 - accuracy: 0.9927 - val_loss: 1.3937 - val_accuracy: 0.7657 - 2s/epoch - 21ms/step
# Epoch 54/80
# 80/80 - 2s - loss: 0.0254 - accuracy: 0.9943 - val_loss: 1.6165 - val_accuracy: 0.7626 - 2s/epoch - 22ms/step
# Epoch 55/80
# 80/80 - 2s - loss: 0.0428 - accuracy: 0.9890 - val_loss: 1.3303 - val_accuracy: 0.7634 - 2s/epoch - 22ms/step
# Epoch 56/80
# 80/80 - 2s - loss: 0.0628 - accuracy: 0.9837 - val_loss: 1.2524 - val_accuracy: 0.7752 - 2s/epoch - 21ms/step
# Epoch 57/80
# 80/80 - 2s - loss: 0.0407 - accuracy: 0.9898 - val_loss: 1.3829 - val_accuracy: 0.7712 - 2s/epoch - 21ms/step
# Epoch 58/80
# 80/80 - 2s - loss: 0.0249 - accuracy: 0.9945 - val_loss: 1.5586 - val_accuracy: 0.7634 - 2s/epoch - 21ms/step
# Epoch 59/80
# 80/80 - 2s - loss: 0.0242 - accuracy: 0.9951 - val_loss: 1.4799 - val_accuracy: 0.7634 - 2s/epoch - 21ms/step
# Epoch 60/80
# 80/80 - 2s - loss: 0.0151 - accuracy: 0.9967 - val_loss: 1.5973 - val_accuracy: 0.7752 - 2s/epoch - 21ms/step
# Epoch 61/80
# 80/80 - 2s - loss: 0.0177 - accuracy: 0.9963 - val_loss: 1.6064 - val_accuracy: 0.7665 - 2s/epoch - 21ms/step
# Epoch 62/80
# 80/80 - 2s - loss: 0.0163 - accuracy: 0.9971 - val_loss: 1.5221 - val_accuracy: 0.7854 - 2s/epoch - 21ms/step
# Epoch 63/80
# 80/80 - 2s - loss: 0.0092 - accuracy: 0.9984 - val_loss: 1.5909 - val_accuracy: 0.7767 - 2s/epoch - 21ms/step
# Epoch 64/80
# 80/80 - 2s - loss: 0.0071 - accuracy: 0.9982 - val_loss: 1.6465 - val_accuracy: 0.7822 - 2s/epoch - 21ms/step
# Epoch 65/80
# 80/80 - 2s - loss: 0.0068 - accuracy: 0.9992 - val_loss: 1.6620 - val_accuracy: 0.7822 - 2s/epoch - 21ms/step
# Epoch 66/80
# 80/80 - 2s - loss: 0.0044 - accuracy: 0.9992 - val_loss: 1.6939 - val_accuracy: 0.7862 - 2s/epoch - 21ms/step
# Epoch 67/80
# 80/80 - 2s - loss: 0.0059 - accuracy: 0.9988 - val_loss: 1.7383 - val_accuracy: 0.7799 - 2s/epoch - 21ms/step
# Epoch 68/80
# 80/80 - 2s - loss: 0.0098 - accuracy: 0.9984 - val_loss: 1.7092 - val_accuracy: 0.7744 - 2s/epoch - 21ms/step
# Epoch 69/80
# 80/80 - 2s - loss: 0.0539 - accuracy: 0.9884 - val_loss: 1.3877 - val_accuracy: 0.7500 - 2s/epoch - 21ms/step
# Epoch 70/80
# 80/80 - 2s - loss: 0.0769 - accuracy: 0.9778 - val_loss: 1.4336 - val_accuracy: 0.7547 - 2s/epoch - 21ms/step
# Epoch 71/80
# 80/80 - 2s - loss: 0.0361 - accuracy: 0.9906 - val_loss: 1.5081 - val_accuracy: 0.7563 - 2s/epoch - 22ms/step
# Epoch 72/80
# 80/80 - 2s - loss: 0.0519 - accuracy: 0.9890 - val_loss: 1.3215 - val_accuracy: 0.7649 - 2s/epoch - 21ms/step
# Epoch 73/80
# 80/80 - 2s - loss: 0.0195 - accuracy: 0.9959 - val_loss: 1.3647 - val_accuracy: 0.7752 - 2s/epoch - 22ms/step
# Epoch 74/80
# 80/80 - 2s - loss: 0.0147 - accuracy: 0.9967 - val_loss: 1.5352 - val_accuracy: 0.7744 - 2s/epoch - 22ms/step
# Epoch 75/80
# 80/80 - 2s - loss: 0.0078 - accuracy: 0.9984 - val_loss: 1.6016 - val_accuracy: 0.7752 - 2s/epoch - 21ms/step
# Epoch 76/80
# 80/80 - 2s - loss: 0.0054 - accuracy: 0.9990 - val_loss: 1.6218 - val_accuracy: 0.7712 - 2s/epoch - 21ms/step
# Epoch 77/80
# 80/80 - 2s - loss: 0.0055 - accuracy: 0.9994 - val_loss: 1.6747 - val_accuracy: 0.7673 - 2s/epoch - 21ms/step
# Epoch 78/80
# 80/80 - 2s - loss: 0.0044 - accuracy: 0.9994 - val_loss: 1.8022 - val_accuracy: 0.7665 - 2s/epoch - 21ms/step
# Epoch 79/80
# 80/80 - 2s - loss: 0.0026 - accuracy: 0.9996 - val_loss: 1.7714 - val_accuracy: 0.7689 - 2s/epoch - 22ms/step
# Epoch 80/80
# 80/80 - 2s - loss: 0.0025 - accuracy: 0.9996 - val_loss: 1.8401 - val_accuracy: 0.7642 - 2s/epoch - 22ms/step
# 40/40 [==============================] - 0s 4ms/step - loss: 1.8401 - accuracy: 0.7642
# [1.8401108980178833, 0.7641509175300598]

# %% [markdown]
# 2. Building GRU model

# %%
# Define parameter
n_gru = 128
drop_gru = 0.3

# Define GRU Model 
model2 = Sequential()
model2.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model2.add(GRU(n_gru))
model2.add(Dropout(drop_gru))
model2.add(Dense(4, activation='softmax'))
model2.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam' , metrics = ['accuracy'])

model2.summary()

history = model2.fit(padded_train_docs,
                     y_train,
                     epochs=num_of_epochs, 
                     batch_size=batch_size,
                     validation_data=(padded_test_docs, y_test),
                     verbose=2)

model2.evaluate(padded_test_docs, y_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 40, 16)            80000
#
#  gru (GRU)                   (None, 128)               56064
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 136580 (533.52 KB)
# Trainable params: 136580 (533.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/80
# 80/80 - 2s - loss: 1.3806 - accuracy: 0.2647 - val_loss: 1.3547 - val_accuracy: 0.3066 - 2s/epoch - 26ms/step
# Epoch 2/80
# 80/80 - 2s - loss: 1.1334 - accuracy: 0.4505 - val_loss: 0.9646 - val_accuracy: 0.5354 - 2s/epoch - 19ms/step
# Epoch 3/80
# 80/80 - 1s - loss: 0.8648 - accuracy: 0.5977 - val_loss: 0.8158 - val_accuracy: 0.6297 - 1s/epoch - 19ms/step
# Epoch 4/80
# 80/80 - 2s - loss: 0.6723 - accuracy: 0.6804 - val_loss: 0.7214 - val_accuracy: 0.6627 - 2s/epoch - 19ms/step
# Epoch 5/80
# 80/80 - 2s - loss: 0.5605 - accuracy: 0.7195 - val_loss: 0.7749 - val_accuracy: 0.6792 - 2s/epoch - 19ms/step
# Epoch 6/80
# 80/80 - 2s - loss: 0.4765 - accuracy: 0.7575 - val_loss: 0.7770 - val_accuracy: 0.6958 - 2s/epoch - 19ms/step
# Epoch 7/80
# 80/80 - 1s - loss: 0.4194 - accuracy: 0.7948 - val_loss: 0.9427 - val_accuracy: 0.6030 - 1s/epoch - 19ms/step
# Epoch 8/80
# 80/80 - 2s - loss: 0.3981 - accuracy: 0.8107 - val_loss: 0.7951 - val_accuracy: 0.7256 - 2s/epoch - 19ms/step
# Epoch 9/80
# 80/80 - 2s - loss: 0.3625 - accuracy: 0.8451 - val_loss: 0.9478 - val_accuracy: 0.7162 - 2s/epoch - 19ms/step
# Epoch 10/80
# 80/80 - 2s - loss: 0.3520 - accuracy: 0.8504 - val_loss: 0.9239 - val_accuracy: 0.7319 - 2s/epoch - 19ms/step
# Epoch 11/80
# 80/80 - 2s - loss: 0.3104 - accuracy: 0.8707 - val_loss: 0.9145 - val_accuracy: 0.7209 - 2s/epoch - 19ms/step
# Epoch 12/80
# 80/80 - 2s - loss: 0.2666 - accuracy: 0.9000 - val_loss: 1.0140 - val_accuracy: 0.7366 - 2s/epoch - 19ms/step
# Epoch 13/80
# 80/80 - 2s - loss: 0.2778 - accuracy: 0.8988 - val_loss: 0.9691 - val_accuracy: 0.7429 - 2s/epoch - 19ms/step
# Epoch 14/80
# 80/80 - 2s - loss: 0.2021 - accuracy: 0.9312 - val_loss: 0.9705 - val_accuracy: 0.7500 - 2s/epoch - 19ms/step
# Epoch 15/80
# 80/80 - 2s - loss: 0.1649 - accuracy: 0.9465 - val_loss: 1.0533 - val_accuracy: 0.7445 - 2s/epoch - 19ms/step
# Epoch 16/80
# 80/80 - 2s - loss: 0.1662 - accuracy: 0.9481 - val_loss: 1.0076 - val_accuracy: 0.7358 - 2s/epoch - 19ms/step
# Epoch 17/80
# 80/80 - 2s - loss: 0.1331 - accuracy: 0.9593 - val_loss: 1.0866 - val_accuracy: 0.7445 - 2s/epoch - 19ms/step
# Epoch 18/80
# 80/80 - 2s - loss: 0.1031 - accuracy: 0.9725 - val_loss: 1.2732 - val_accuracy: 0.7476 - 2s/epoch - 19ms/step
# Epoch 19/80
# 80/80 - 2s - loss: 0.0966 - accuracy: 0.9717 - val_loss: 1.1184 - val_accuracy: 0.7414 - 2s/epoch - 19ms/step
# Epoch 20/80
# 80/80 - 2s - loss: 0.0977 - accuracy: 0.9729 - val_loss: 1.2640 - val_accuracy: 0.7453 - 2s/epoch - 19ms/step
# Epoch 21/80
# 80/80 - 2s - loss: 0.0911 - accuracy: 0.9750 - val_loss: 1.2204 - val_accuracy: 0.7563 - 2s/epoch - 19ms/step
# Epoch 22/80
# 80/80 - 2s - loss: 0.0673 - accuracy: 0.9831 - val_loss: 1.3350 - val_accuracy: 0.7524 - 2s/epoch - 19ms/step
# Epoch 23/80
# 80/80 - 2s - loss: 0.0812 - accuracy: 0.9784 - val_loss: 1.3198 - val_accuracy: 0.7453 - 2s/epoch - 19ms/step
# Epoch 24/80
# 80/80 - 2s - loss: 0.0816 - accuracy: 0.9768 - val_loss: 1.4630 - val_accuracy: 0.7437 - 2s/epoch - 19ms/step
# Epoch 25/80
# 80/80 - 2s - loss: 0.0497 - accuracy: 0.9890 - val_loss: 1.4997 - val_accuracy: 0.7390 - 2s/epoch - 20ms/step
# Epoch 26/80
# 80/80 - 2s - loss: 0.0335 - accuracy: 0.9949 - val_loss: 1.5972 - val_accuracy: 0.7390 - 2s/epoch - 21ms/step
# Epoch 27/80
# 80/80 - 2s - loss: 0.0286 - accuracy: 0.9959 - val_loss: 1.6267 - val_accuracy: 0.7335 - 2s/epoch - 22ms/step
# Epoch 28/80
# 80/80 - 2s - loss: 0.0286 - accuracy: 0.9963 - val_loss: 1.5630 - val_accuracy: 0.7484 - 2s/epoch - 22ms/step
# Epoch 29/80
# 80/80 - 2s - loss: 0.0238 - accuracy: 0.9963 - val_loss: 1.6116 - val_accuracy: 0.7445 - 2s/epoch - 19ms/step
# Epoch 30/80
# 80/80 - 2s - loss: 0.0286 - accuracy: 0.9943 - val_loss: 1.4610 - val_accuracy: 0.7492 - 2s/epoch - 20ms/step
# Epoch 31/80
# 80/80 - 2s - loss: 0.1099 - accuracy: 0.9670 - val_loss: 1.3792 - val_accuracy: 0.7406 - 2s/epoch - 20ms/step
# Epoch 32/80
# 80/80 - 2s - loss: 0.0814 - accuracy: 0.9784 - val_loss: 1.4159 - val_accuracy: 0.7343 - 2s/epoch - 20ms/step
# Epoch 33/80
# 80/80 - 2s - loss: 0.0563 - accuracy: 0.9855 - val_loss: 1.2354 - val_accuracy: 0.7500 - 2s/epoch - 22ms/step
# Epoch 34/80
# 80/80 - 2s - loss: 0.0436 - accuracy: 0.9917 - val_loss: 1.5732 - val_accuracy: 0.7382 - 2s/epoch - 19ms/step
# Epoch 35/80
# 80/80 - 2s - loss: 0.0287 - accuracy: 0.9955 - val_loss: 1.4870 - val_accuracy: 0.7453 - 2s/epoch - 19ms/step
# Epoch 36/80
# 80/80 - 1s - loss: 0.0265 - accuracy: 0.9953 - val_loss: 1.5635 - val_accuracy: 0.7437 - 1s/epoch - 19ms/step
# Epoch 37/80
# 80/80 - 1s - loss: 0.0255 - accuracy: 0.9957 - val_loss: 1.4930 - val_accuracy: 0.7453 - 1s/epoch - 18ms/step
# Epoch 38/80
# 80/80 - 1s - loss: 0.0194 - accuracy: 0.9969 - val_loss: 1.5171 - val_accuracy: 0.7508 - 1s/epoch - 18ms/step
# Epoch 39/80
# 80/80 - 1s - loss: 0.0188 - accuracy: 0.9972 - val_loss: 1.7365 - val_accuracy: 0.7421 - 1s/epoch - 18ms/step
# Epoch 40/80
# 80/80 - 1s - loss: 0.0177 - accuracy: 0.9972 - val_loss: 1.6555 - val_accuracy: 0.7437 - 1s/epoch - 18ms/step
# Epoch 41/80
# 80/80 - 1s - loss: 0.0155 - accuracy: 0.9980 - val_loss: 1.7795 - val_accuracy: 0.7414 - 1s/epoch - 18ms/step
# Epoch 42/80
# 80/80 - 1s - loss: 0.0133 - accuracy: 0.9982 - val_loss: 1.7547 - val_accuracy: 0.7500 - 1s/epoch - 18ms/step
# Epoch 43/80
# 80/80 - 1s - loss: 0.0154 - accuracy: 0.9976 - val_loss: 1.6661 - val_accuracy: 0.7398 - 1s/epoch - 18ms/step
# Epoch 44/80
# 80/80 - 1s - loss: 0.0239 - accuracy: 0.9961 - val_loss: 1.6286 - val_accuracy: 0.7524 - 1s/epoch - 19ms/step
# Epoch 45/80
# 80/80 - 1s - loss: 0.0280 - accuracy: 0.9931 - val_loss: 1.6642 - val_accuracy: 0.7555 - 1s/epoch - 18ms/step
# Epoch 46/80
# 80/80 - 1s - loss: 0.0779 - accuracy: 0.9764 - val_loss: 1.5852 - val_accuracy: 0.7437 - 1s/epoch - 18ms/step
# Epoch 47/80
# 80/80 - 1s - loss: 0.1382 - accuracy: 0.9591 - val_loss: 1.2054 - val_accuracy: 0.7280 - 1s/epoch - 19ms/step
# Epoch 48/80
# 80/80 - 1s - loss: 0.0671 - accuracy: 0.9813 - val_loss: 1.3602 - val_accuracy: 0.7516 - 1s/epoch - 18ms/step
# Epoch 49/80
# 80/80 - 1s - loss: 0.0352 - accuracy: 0.9931 - val_loss: 1.4103 - val_accuracy: 0.7579 - 1s/epoch - 18ms/step
# Epoch 50/80
# 80/80 - 1s - loss: 0.0163 - accuracy: 0.9974 - val_loss: 1.7190 - val_accuracy: 0.7469 - 1s/epoch - 18ms/step
# Epoch 51/80
# 80/80 - 1s - loss: 0.0128 - accuracy: 0.9982 - val_loss: 1.6809 - val_accuracy: 0.7539 - 1s/epoch - 18ms/step
# Epoch 52/80
# 80/80 - 1s - loss: 0.0117 - accuracy: 0.9984 - val_loss: 1.7709 - val_accuracy: 0.7469 - 1s/epoch - 18ms/step
# Epoch 53/80
# 80/80 - 1s - loss: 0.0124 - accuracy: 0.9982 - val_loss: 1.8085 - val_accuracy: 0.7484 - 1s/epoch - 18ms/step
# Epoch 54/80
# 80/80 - 1s - loss: 0.0121 - accuracy: 0.9984 - val_loss: 1.7670 - val_accuracy: 0.7500 - 1s/epoch - 18ms/step
# Epoch 55/80
# 80/80 - 1s - loss: 0.0122 - accuracy: 0.9984 - val_loss: 1.9059 - val_accuracy: 0.7358 - 1s/epoch - 19ms/step
# Epoch 56/80
# 80/80 - 2s - loss: 0.0113 - accuracy: 0.9984 - val_loss: 1.8707 - val_accuracy: 0.7453 - 2s/epoch - 19ms/step
# Epoch 57/80
# 80/80 - 1s - loss: 0.0121 - accuracy: 0.9984 - val_loss: 1.9462 - val_accuracy: 0.7421 - 1s/epoch - 19ms/step
# Epoch 58/80
# 80/80 - 1s - loss: 0.0111 - accuracy: 0.9984 - val_loss: 1.8922 - val_accuracy: 0.7484 - 1s/epoch - 18ms/step
# Epoch 59/80
# 80/80 - 1s - loss: 0.0106 - accuracy: 0.9982 - val_loss: 1.7692 - val_accuracy: 0.7586 - 1s/epoch - 18ms/step
# Epoch 60/80
# 80/80 - 1s - loss: 0.0124 - accuracy: 0.9982 - val_loss: 1.8941 - val_accuracy: 0.7445 - 1s/epoch - 18ms/step
# Epoch 61/80
# 80/80 - 1s - loss: 0.0362 - accuracy: 0.9904 - val_loss: 1.6519 - val_accuracy: 0.7524 - 1s/epoch - 18ms/step
# Epoch 62/80
# 80/80 - 1s - loss: 0.0387 - accuracy: 0.9919 - val_loss: 1.6575 - val_accuracy: 0.7398 - 1s/epoch - 19ms/step
# Epoch 63/80
# 80/80 - 1s - loss: 0.0603 - accuracy: 0.9819 - val_loss: 1.5434 - val_accuracy: 0.7586 - 1s/epoch - 19ms/step
# Epoch 64/80
# 80/80 - 1s - loss: 0.0401 - accuracy: 0.9886 - val_loss: 1.5577 - val_accuracy: 0.7626 - 1s/epoch - 19ms/step
# Epoch 65/80
# 80/80 - 1s - loss: 0.0276 - accuracy: 0.9947 - val_loss: 1.6174 - val_accuracy: 0.7563 - 1s/epoch - 19ms/step
# Epoch 66/80
# 80/80 - 1s - loss: 0.0173 - accuracy: 0.9957 - val_loss: 1.8222 - val_accuracy: 0.7571 - 1s/epoch - 19ms/step
# Epoch 67/80
# 80/80 - 2s - loss: 0.0240 - accuracy: 0.9935 - val_loss: 1.6632 - val_accuracy: 0.7697 - 2s/epoch - 19ms/step
# Epoch 68/80
# 80/80 - 2s - loss: 0.0298 - accuracy: 0.9923 - val_loss: 1.6430 - val_accuracy: 0.7571 - 2s/epoch - 19ms/step
# Epoch 69/80
# 80/80 - 2s - loss: 0.0207 - accuracy: 0.9961 - val_loss: 1.6047 - val_accuracy: 0.7610 - 2s/epoch - 19ms/step
# Epoch 70/80
# 80/80 - 2s - loss: 0.0167 - accuracy: 0.9969 - val_loss: 1.7398 - val_accuracy: 0.7610 - 2s/epoch - 19ms/step
# Epoch 71/80
# 80/80 - 2s - loss: 0.0311 - accuracy: 0.9925 - val_loss: 1.7047 - val_accuracy: 0.7594 - 2s/epoch - 19ms/step
# Epoch 72/80
# 80/80 - 1s - loss: 0.0205 - accuracy: 0.9961 - val_loss: 1.6667 - val_accuracy: 0.7673 - 1s/epoch - 19ms/step
# Epoch 73/80
# 80/80 - 2s - loss: 0.0124 - accuracy: 0.9974 - val_loss: 1.6618 - val_accuracy: 0.7704 - 2s/epoch - 19ms/step
# Epoch 74/80
# 80/80 - 2s - loss: 0.0104 - accuracy: 0.9982 - val_loss: 1.8447 - val_accuracy: 0.7657 - 2s/epoch - 19ms/step
# Epoch 75/80
# 80/80 - 2s - loss: 0.0124 - accuracy: 0.9967 - val_loss: 1.7002 - val_accuracy: 0.7634 - 2s/epoch - 19ms/step
# Epoch 76/80
# 80/80 - 1s - loss: 0.0139 - accuracy: 0.9972 - val_loss: 1.7366 - val_accuracy: 0.7657 - 1s/epoch - 19ms/step
# Epoch 77/80
# 80/80 - 1s - loss: 0.0121 - accuracy: 0.9974 - val_loss: 1.8635 - val_accuracy: 0.7500 - 1s/epoch - 19ms/step
# Epoch 78/80
# 80/80 - 2s - loss: 0.0079 - accuracy: 0.9988 - val_loss: 1.9625 - val_accuracy: 0.7531 - 2s/epoch - 19ms/step
# Epoch 79/80
# 80/80 - 2s - loss: 0.0093 - accuracy: 0.9976 - val_loss: 1.8797 - val_accuracy: 0.7649 - 2s/epoch - 19ms/step
# Epoch 80/80
# 80/80 - 2s - loss: 0.0117 - accuracy: 0.9971 - val_loss: 1.8621 - val_accuracy: 0.7618 - 2s/epoch - 19ms/step
# 40/40 [==============================] - 0s 3ms/step - loss: 1.8621 - accuracy: 0.7618
# [1.8620737791061401, 0.7617924809455872]

# %% [markdown]
# # Performance metrics

# %% [markdown]
# 1. LSTM performance

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.utils import to_categorical
y_test_categorical = to_categorical(y_test, num_classes=4)

y_pred = model1.predict(padded_test_docs)
# Find the index of the maximum value across the columns
max_indices = np.argmax(y_pred, axis=1)

# Reshape the resulting array to have a single column
max_indices = max_indices.reshape(-1, 1)
# print(padded_test_docs)

# # Compute precision
precision = precision_score(y_test, max_indices, average='weighted')

# Compute recall
recall = recall_score(y_test, max_indices, average='weighted')

# Compute F1 score
f1 = f1_score(y_test, max_indices, average='weighted')

# # Print the results
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# 40/40 [==============================] - 0s 4ms/step
# Precision: 0.7493632815642122
# Recall: 0.7641509433962265
# F1 Score: 0.7540753539199905

# %% [markdown]
# 2. GRU performance

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.utils import to_categorical
y_test_categorical = to_categorical(y_test, num_classes=4)

y_pred = model2.predict(padded_test_docs)

# Find the index of the maximum value across the columns
max_indices = np.argmax(y_pred, axis=1)

# Reshape the resulting array to have a single column
max_indices = max_indices.reshape(-1, 1)

# # Compute precision
precision = precision_score(y_test, max_indices, average='weighted')

# Compute recall
recall = recall_score(y_test, max_indices, average='weighted')

# Compute F1 score
f1 = f1_score(y_test, max_indices, average='weighted')

# # Print the results
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# 40/40 [==============================] - 0s 3ms/step
# Precision: 0.744828850941714
# Recall: 0.7617924528301887
# F1 Score: 0.7485443632884842
